# %% [markdown]
# ### Linear Regression - Best fit line

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from sklearn import metrics
import pickle
from matplotlib import style
# %matplotlib inline

# %%
# bring in your data

data = pd.read_csv('student-mat.csv', sep = ';')

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# identify the data (attributes) you want to use

data = data[['G1', 'G2', 'G3', 'studytime', 'failures', 'absences']]

pd.set_option('display.max_rows', None)

data
# Out:
#      G1  G2  G3  studytime  failures  absences
# 0     5   6   6          2         0         6
# 1     5   5   6          2         0         4
# 2     7   8  10          2         3        10
# 3    15  14  15          3         0         2
# 4     6  10  10          2         0         4
# 5    15  15  15          2         0        10
# 6    12  12  11          2         0         0
# 7     6   5   6          2         0         6
# 8    16  18  19          2         0         0
# 9    14  15  15          2         0         0
# 10   10   8   9          2         0         0
# 11   10  12  12          3         0         4
# 12   14  14  14          1         0         2
# 13   10  10  11          2         0         2
# 14   14  16  16          3         0         0
# 15   14  14  14          1         0         4
# 16   13  14  14          3         0         6
# 17    8  10  10          2         0         4
# 18    6   5   5          1         3        16
# ...

# %%
data.shape
# Out:
# (395, 6)

# %%
data.describe()
# Out:
#                G1          G2          G3   studytime    failures    absences
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190    2.035443    0.334177    5.708861
# std      3.319195    3.761505    4.581443    0.839240    0.743651    8.003096
# min      3.000000    0.000000    0.000000    1.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000    1.000000    0.000000    0.000000
# 50%     11.000000   11.000000   11.000000    2.000000    0.000000    4.000000
# 75%     13.000000   13.000000   14.000000    2.000000    0.000000    8.000000
# max     19.000000   19.000000   20.000000    4.000000    3.000000   75.000000

# %%
data.isnull()
# Out:
#         G1     G2     G3  studytime  failures  absences
# 0    False  False  False      False     False     False
# 1    False  False  False      False     False     False
# 2    False  False  False      False     False     False
# 3    False  False  False      False     False     False
# 4    False  False  False      False     False     False
# 5    False  False  False      False     False     False
# 6    False  False  False      False     False     False
# 7    False  False  False      False     False     False
# 8    False  False  False      False     False     False
# 9    False  False  False      False     False     False
# 10   False  False  False      False     False     False
# 11   False  False  False      False     False     False
# 12   False  False  False      False     False     False
# 13   False  False  False      False     False     False
# 14   False  False  False      False     False     False
# 15   False  False  False      False     False     False
# ...

# %%
data.corr()
# Out:
#                  G1        G2        G3  studytime  failures  absences
# G1         1.000000  0.852118  0.801468   0.160612 -0.354718 -0.031003
# G2         0.852118  1.000000  0.904868   0.135880 -0.355896 -0.031777
# G3         0.801468  0.904868  1.000000   0.097820 -0.360415  0.034247
# studytime  0.160612  0.135880  0.097820   1.000000 -0.173563 -0.062700
# failures  -0.354718 -0.355896 -0.360415  -0.173563  1.000000  0.063726
# absences  -0.031003 -0.031777  0.034247  -0.062700  0.063726  1.000000

# %%
# define our prediction (G3 - students final grade)
# get our label (G3) based on given attributes

predict = 'G3'
# set up arrays to define our features/attributes and labels
# features
x = np.array(data.drop([predict], 1))

# labels
y = np.array(data[predict])

# %%
# split our arrays into four variables to train and test our data (test_size = 10%)
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.1)

# create a training model

linear = linear_model.LinearRegression()

# fit our data to find a best fit line

linear.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# score our model

accuracy = linear.score(x_test, y_test)
accuracy
# Out:
# 0.7624695648777013

# %% [markdown]
# #### test our model on data

# %%
# our constants (Y = mx+b, m - slope, y - intecept)

print('Coefficient: \n', linear.coef_) # For retrieving the slope
print('Intercept: \n', linear.intercept_)# To retrieve the intercept (y)
# Out:
# Coefficient:
#  [ 0.16002261  0.97496112 -0.14920684 -0.2702566   0.03302603]
# Intercept:
#  -1.5599772078006389

# %%
# make predicitions on test data
# predict student grade
pred = linear.predict(x_test)

# print out all predictions, input data, actual value of final grade
for x in range(len(pred)):
   print(pred[x], x_test[x], y_test[x])
# Out:
# 9.138872380337906 [11  9  2  0 14] 9
# 7.001009059924355 [ 9  7  2  0 18] 6
# 7.11124495622431 [9 8 2 1 0] 0
# 14.031381328080737 [14 14  2  0  0] 14
# -0.42900318503892154 [8 0 1 0 0] 0
# 15.298469195666659 [15 15  2  0  4] 15
# 11.827465938540803 [12 12  2  0  2] 11
# 11.149739127795508 [12 11  2  0 11] 11
# 5.441794446566526 [ 7  6  2  0 10] 6
# 8.003888651004749 [10  8  2  0 14] 9
# 6.444674037646919 [8 7 2 0 6] 9
# 12.642404452835677 [11 13  2  0  2] 13
# 14.455612212105407 [15 14  2  0  8] 14
# 11.959570076793568 [12 12  2  0  6] 12
# 8.36146682636894 [ 8  8  1  0 30] 8
# 5.855209560463473 [ 7  6  1  0 18] 6
# 10.775636977472681 [11 11  1  0  0] 10
# 15.13844658814752 [14 15  2  0  4] 15
# 8.703825726185512 [9 9 1 0 6] 10
# 9.31432110409031 [ 9 10  3  0  4] 10
# 4.9896450932754774 [5 6 2 0 6] 6
# 16.22958851278976 [14 16  1  0  3] 16
# 10.664563739941268 [10 11  2  0  6] 11
# 8.460648350401334 [8 9 2 0 8] 10
# 9.463527941481727 [ 9 10  2  0  4] 10
# ...

# %% [markdown]
# #### plotting data

# %%
# correlation
p = 'G1'
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 5), dpi=80, facecolor='w', edgecolor='green')
plt.scatter(data[p], data['G3'])
plt.title('Correlation', fontsize = 14)
plt.xlabel(p)
plt.ylabel('Final Grades')
plt.grid()
plt.show()

# %% [markdown]
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors.
# Mean Squared Error (MSE) is the mean of the squared errors.
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors.

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Mean Absolute Error: 1.080751045428411
# Mean Squared Error: 4.162572418996334
# Root Mean Squared Error: 2.0402383240681305
